# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA) on Cryptocurrency Market (2017 & 2018)
#
# ## 🎯 Objective
# To analyze the **cryptocurrency market trends** between **2017 and 2018**, focusing on **market capitalization**, **top cryptocurrencies**, and **Bitcoin’s growth** using **Python libraries** like Pandas, Matplotlib, and Seaborn.
#
# ---
#
# ## 🔍 Key Insights & Findings
#
# ### 1️⃣ Data Overview & Cleaning
# ✔ The dataset contains details on **market cap, price, and supply** of cryptocurrencies.
# ✔ **Missing values** were handled by replacing them with **0**.
#
# ### 2️⃣ Market Capitalization Trends
# 📌 **Market cap distribution changed** significantly from 2017 to 2018.
# 📌 Many cryptocurrencies **grew**, but more small-cap coins emerged.
# 📈 **Bitcoin’s market cap increased**, reflecting its strong market position.
#
# ### 3️⃣ Top 10 Cryptocurrencies (2017 & 2018)
# ✔ **New coins** gained market share in 2018.
# ✔ **Bitcoin, Ethereum, and Ripple remained dominant**, but shifts in rankings were observed.
#
#
# ### 4️⃣ Visualizations Used
# 📊 **Histograms** – Market cap distribution comparison.
# 📈 **Bar Charts** – Top 10 cryptocurrencies by market cap.
#
# ---
#
# ## 🚀 Conclusion & Future Scope
# 🔹 **The crypto market evolved significantly**, with shifts in dominance and new players emerging.
# 🔹 **Bitcoin remained the leader**, but alternative cryptocurrencies gained traction.
# 🔹 **Future analysis** could include **2020-2024 data**, **time-series forecasting**, and **price-trading volume correlation**.

# %% [markdown]
# # 🔹 Step 1: Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 🔹 Step 2.1: Load the Data 1

# %%
df1=pd.read_csv(r"C:\Users\USER\Downloads\eda-crypto-master\datasets\coinmarketcap_06012018.csv")
df2=pd.read_csv(r"C:\Users\USER\Downloads\eda-crypto-master\datasets\coinmarketcap_06122017.csv")
df1.info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          100 non-null    int64
#  1   24h_volume_usd      100 non-null    int64
#  2   available_supply    100 non-null    int64
#  3   id                  100 non-null    object
#  4   last_updated        100 non-null    int64
#  5   market_cap_usd      100 non-null    int64
#  6   max_supply          27 non-null     float64
#  7   name                100 non-null    object
#  8   percent_change_1h   100 non-null    float64
#  9   percent_change_24h  100 non-null    float64
#  10  percent_change_7d   100 non-null    float64
#  11  price_btc           100 non-null    float64
#  12  price_usd           100 non-null    float64
#  13  rank                100 non-null    int64
#  14  symbol              100 non-null    object
# ...

# %% [markdown]
# # Step 2.2: Load the Data 2

# %%
df2=pd.read_csv(r"C:\Users\USER\Downloads\eda-crypto-master\datasets\coinmarketcap_06122017.csv")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1326 entries, 0 to 1325
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1326 non-null   int64
#  1   24h_volume_usd      1270 non-null   float64
#  2   available_supply    1031 non-null   float64
#  3   id                  1326 non-null   object
#  4   last_updated        1326 non-null   int64
#  5   market_cap_usd      1031 non-null   float64
#  6   max_supply          215 non-null    float64
#  7   name                1326 non-null   object
#  8   percent_change_1h   1273 non-null   float64
#  9   percent_change_24h  1270 non-null   float64
#  10  percent_change_7d   1283 non-null   float64
#  11  price_btc           1326 non-null   float64
#  12  price_usd           1326 non-null   float64
#  13  rank                1326 non-null   int64
#  14  symbol              1326 non-null   object
# ...

# %% [markdown]
# # 🔹 Step 4.1: Handle Missing Values

# %%
print(df1.isnull().sum())

# Filling missing values with zero
df1.fillna(0, inplace=True)
# Out:
# Unnamed: 0            0
# 24h_volume_usd        0
# available_supply      0
# id                    0
# last_updated          0
# market_cap_usd        0
# max_supply            0
# name                  0
# percent_change_1h     0
# percent_change_24h    0
# percent_change_7d     0
# price_btc             0
# price_usd             0
# rank                  0
# symbol                0
# total_supply          0
# dtype: int64

# %% [markdown]
# #  Step 4.2: Handle Missing Values

# %%
print(df2.isnull().sum())

# Filling missing values with zero
df2.fillna(0, inplace=True)
# Out:
# Unnamed: 0            0
# 24h_volume_usd        0
# available_supply      0
# id                    0
# last_updated          0
# market_cap_usd        0
# max_supply            0
# name                  0
# percent_change_1h     0
# percent_change_24h    0
# percent_change_7d     0
# price_btc             0
# price_usd             0
# rank                  0
# symbol                0
# total_supply          0
# dtype: int64

# %%
print(df1.describe())
# Out:
#        Unnamed: 0  24h_volume_usd  available_supply  last_updated  \
# count  100.000000    1.000000e+02      1.000000e+02  1.000000e+02
# mean    49.500000    5.313066e+08      4.397534e+10  1.515231e+09
# std     29.011492    2.354403e+09      2.636906e+11  5.135920e+00
# min      0.000000    3.895190e+05      6.452220e+05  1.515231e+09
# 25%     24.750000    1.983332e+07      5.478988e+07  1.515231e+09
# 50%     49.500000    4.442795e+07      2.045273e+08  1.515231e+09
# 75%     74.250000    1.713828e+08      1.502973e+09  1.515231e+09
# max     99.000000    2.208130e+10      2.509984e+12  1.515231e+09
#
#        market_cap_usd    max_supply  percent_change_1h  percent_change_24h  \
# count    1.000000e+02  1.000000e+02         100.000000          100.000000
# mean     7.608243e+09  8.400078e+10           0.051700           11.169200
# std      3.234455e+10  7.998840e+11           2.592407           34.088136
# ...

# %%
print(df2.describe())
# Out:
#         Unnamed: 0  24h_volume_usd  available_supply  last_updated  \
# count  1326.000000    1.326000e+03      1.326000e+03  1.326000e+03
# mean    662.500000    1.576096e+07      6.731174e+09  1.512545e+09
# std     382.927539    2.682129e+08      1.006237e+11  3.793006e+04
# min       0.000000    0.000000e+00      0.000000e+00  1.511626e+09
# 25%     331.250000    1.998015e+02      1.982838e+05  1.512550e+09
# 50%     662.500000    3.608105e+03      1.000000e+07  1.512550e+09
# 75%     993.750000    1.768362e+05      7.384089e+07  1.512550e+09
# max    1325.000000    9.007640e+09      3.209033e+12  1.512550e+09
#
#        market_cap_usd    max_supply  percent_change_1h  percent_change_24h  \
# count    1.326000e+03  1.326000e+03        1326.000000         1326.000000
# mean     2.822812e+08  7.548378e+11           1.010370            8.290128
# std      6.036939e+09  2.746173e+13          11.764749           43.105863
# ...

# %% [markdown]
# ## Top 10 market capitalization &
# ## Market Capitalization Distribution using Histoplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.histplot(df1['market_cap_usd'], bins=50, kde=True, color='blue', label='Jan 2018')
sns.histplot(df2['market_cap_usd'], bins=50, kde=True, color='red', label='Dec 2017')
plt.xscale("log")
plt.legend()
plt.title("Market Capitalization Distribution")
plt.xlabel("Market Cap (USD)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Top 10 Cryptocurrencies by Market Cap (Jan 2018) using Barplot

# %%
top10_2018 = df1.nlargest(10, 'market_cap_usd')

plt.figure(figsize=(12, 6))
sns.barplot(y=top10_2018['name'],hue=top10_2018['name'], x=top10_2018['market_cap_usd'], palette='Blues_r')
plt.xlabel("Market Cap (USD)")
plt.ylabel("Cryptocurrency")
plt.title("Top 10 Cryptocurrencies by Market Cap (Jan 2018)")
plt.show()

# %% [markdown]
# # Top 10 Cryptocurrencies by Market Cap (Jan 2017) using Barplot

# %%
top10_2018 = df2.nlargest(10, 'market_cap_usd')

plt.figure(figsize=(12, 6))
sns.barplot(y=top10_2018['name'],hue=top10_2018['name'], x=top10_2018['market_cap_usd'], palette='Blues_r')
plt.xlabel("Market Cap (USD)")
plt.ylabel("Cryptocurrency")
plt.title("Top 10 Cryptocurrencies by Market Cap (Jan 2017)")
plt.show()

# %% [markdown]
# #  Price vs Market Cap (Jan 2018) using Scatterplot

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df1, x='market_cap_usd', y='price_usd', alpha=0.5)
plt.xscale("log")
plt.yscale("log")
plt.title("Price vs Market Cap (Jan 2018)")
plt.xlabel("Market Cap (USD)")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# # Feature Correlation (Jan 2018) using Heatmap

# %%
# Select only numeric columns
numeric_df1 = df1.select_dtypes(include=['number'])

# Generate correlation heatmap
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df1.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation (Jan 2018)")
plt.show()

# %% [markdown]
# #   Feature Correlation (Jan 2017) using Heatmap

# %%
# Select only numeric columns
numeric_df2 = df2.select_dtypes(include=['number'])

# Generate correlation heatmap
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df2.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation (Jan 2017)")
plt.show()

# %% [markdown]
# # Price Distribution using Histplot

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df1['price_usd'], bins=50, kde=True, color='green', label='Jan 2018')
sns.histplot(df2['price_usd'], bins=50, kde=True, color='purple', label='Dec 2017')
plt.xscale("log")
plt.legend()
plt.title("Price Distribution")
plt.xlabel("Price (USD)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #  24h Percentage Change Distribution (Jan 2017) using Boxplot

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df2, x='percent_change_24h', color='blue')
plt.title("24h Percentage Change Distribution (Jan 2017)")
plt.xlabel("Percentage Change")
plt.show()

# %% [markdown]
# #  Total Supply vs Market Cap (Jan 2018) using Scatterplot

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df1, x='total_supply', y='market_cap_usd', alpha=0.5)
plt.xscale("log")
plt.yscale("log")
plt.title("Total Supply vs Market Cap (Jan 2018)")
plt.xlabel("Total Supply")
plt.ylabel("Market Cap (USD)")
plt.show()
